# %% [markdown]
# <a href="https://colab.research.google.com/github/VanessaEscobar1107/alura-store-challenge/blob/main/alura_store_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# URLs de los CSV en GitHub
url1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_4.csv"

# Cargar datos
tienda1 = pd.read_csv(url1)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# Agregar la columna 'Tienda'
tienda1['Tienda'] = 'Tienda 1'
tienda2['Tienda'] = 'Tienda 2'
tienda3['Tienda'] = 'Tienda 3'
tienda4['Tienda'] = 'Tienda 4'

# Unir todos los datos en un solo DataFrame
datos = pd.concat([tienda1, tienda2, tienda3, tienda4], ignore_index=True)

# --- ANÁLISIS GENERAL ---
print("Forma del Dataframe:", datos.shape)
print("Columnas:", datos.columns)
print("Valores nulos por columnas:\n", datos.isnull().sum())
print("Estadísticas generales:\n", datos.describe())

# Productos más vendidos (top 10)
productos_mas_vendidos = datos['Producto'].value_counts().head(10)
print("Productos más vendidos:\n", productos_mas_vendidos)

# Categorías más compradas
categorias = datos['Categoría del Producto'].value_counts()
print("Categorías más populares:\n", categorias)

# Métodos de pago más comunes
metodos_pago = datos['Método de pago'].value_counts()
print("Métodos de pago:\n", metodos_pago)

# Calificación promedio general
calificacion_promedio_total = datos['Calificación'].mean()
print(f'Calificación promedio general: {calificacion_promedio_total:.2f}')

# --- ANÁLISIS POR TIENDA ---

# Facturación total por tienda
datos['Total venta'] = datos['Precio'] + datos['Costo de envío']
facturacion = datos.groupby('Tienda')['Total venta'].sum()
print("\nFacturación total por tienda:\n", facturacion)

# Categorías más populares por tienda
categorias_populares = datos.groupby(['Tienda', 'Categoría del Producto']).size().reset_index(name='Cantidad')
categorias_top = categorias_populares.sort_values(['Tienda', 'Cantidad'], ascending=[True, False]).groupby('Tienda').first()
print("\nCategoría más popular por tienda:\n", categorias_top)

# Calificación promedio por tienda
calificacion_promedio = datos.groupby('Tienda')['Calificación'].mean()
print("\nCalificación promedio por tienda:\n", calificacion_promedio)

# Productos más vendidos por tienda
productos_tienda = datos.groupby(['Tienda', 'Producto']).size().reset_index(name='Cantidad')
mas_vendidos = productos_tienda.sort_values(['Tienda', 'Cantidad'], ascending=[True, False])
top_productos = mas_vendidos.groupby('Tienda').first()
print("\nProducto más vendido por tienda:\n", top_productos)

# Productos menos vendidos por tienda
menos_vendidos = productos_tienda.sort_values(['Tienda', 'Cantidad'], ascending=[True, True])
bottom_productos = menos_vendidos.groupby('Tienda').first()
print("\nProducto menos vendido por tienda:\n", bottom_productos)

# Costo promedio del envío por tienda
costo_envio_promedio = datos.groupby('Tienda')['Costo de envío'].mean()
print("\nCosto promedio del envío por tienda:\n", costo_envio_promedio)
# Out:
# Forma del Dataframe: (9435, 13)
# Columnas: Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon', 'Tienda'],
#       dtype='object')
# Valores nulos por columnas:
#  Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# Tienda                    0
# dtype: int64
# Estadísticas generales:
#               Precio  Costo de envío  Calificación  Cantidad de cuotas  \
# count  9.435000e+03     9435.000000   9435.000000         9435.000000
# mean   4.667323e+05    24875.145734      4.014520            2.927398
# ...

# %% [markdown]
# ## Análisis y conclusiones
#
# **Facturación por tienda**
# La tienda con mayor facturación es la Tienda 1, mientras que la Tienda 3 presenta la facturación más baja.
#
# **Calificación promedio**
# La calificación más alta fue para la Tienda 1; en donde los clientes han estado más satisfechos y la más baja en la Tienda 3.
#
# **Costo de envío promedio**
# La Tienda 3 tiene el costo de envío más alto, por ende puede afectar la satisfacción del cliente.
#
# **Productos más y menos vendidos**
# La Tienda 3 también presenta varios productos con ventas muy bajas, esto indica posibles problemas de inventario y popularidad.
#
# ### Recomendación
#
# En base al análisis anterior, se recomienda **vender la Tienda 3**, ya que no tiene un buen rendimiento.
